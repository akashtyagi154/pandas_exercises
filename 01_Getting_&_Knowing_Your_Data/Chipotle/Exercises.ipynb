# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
chipo
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
len(chipo)
# Out:
# 4622

# %%
# Solution 2

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
most_ordered_item = chipo.groupby('item_name')[['quantity']].sum().sort_values('quantity',ascending=False).reset_index()
most_ordered_itemm = most_ordered_item.head(1)
most_ordered_itemm['item_name']
# Out:
# 0    Chicken Bowl
# Name: item_name, dtype: object

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
most_ordered_itemm['quantity']
# Out:
# 0    761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
msd = chipo.groupby('choice_description').sum().sort_values('quantity',ascending=False)
msd.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %%
chipo['item_price1'] = chipo.item_price.str.split('$',expand=True)[1]

chipo['item_price1'] = chipo.item_price1.astype(float)

# %%
chipo['item_price'] = chipo['item_price1']
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo
# Out:
#       order_id  quantity  ... item_price1     sales
# 0            1         1  ...        2.39      2.39
# 1            1         1  ...        3.39      3.39
# 2            1         1  ...        3.39      3.39
# 3            1         1  ...        2.39      2.39
# 4            2         2  ...       16.98     33.96
# ...        ...       ...  ...         ...       ...
# 4617      1833         1  ...       11.75  21537.75
# 4618      1833         1  ...       11.75  21537.75
# 4619      1834         1  ...       11.25  20632.50
# 4620      1834         1  ...        8.75  16047.50
# 4621      1834         1  ...        8.75  16047.50
#
# [4622 rows x 7 columns]

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['sales'] = chipo.quantity * chipo.item_price
'$'+str(chipo['sales' ].sum())
# Out:
# '$39237.02'

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
# len(chipo.order_id.unique())
chipo.order_id.value_counts().count()
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipo.groupby('order_id')[['sales']].sum()['sales'].mean()
# Out:
# 21.394231188658654

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
# len(chipo.item_name.unique())
chipo.item_name.value_counts().count()
# Out:
# 50
